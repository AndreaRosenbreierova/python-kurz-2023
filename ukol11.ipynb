# %%
import pandas as pd
import matplotlib.pyplot as plt
platy_2021 = pd.read_csv("platy_2021_02.csv")
platy_2021.head()
# Out:
#    cislo_zamestnance     plat
# 0                  3  54900.0
# 1                  6  54800.0
# 2                  7  36400.0
# 3                  8  47900.0
# 4                 16  34200.0

# %%
platy_2021["plat"].hist(bins=range(30000, 60000, 1000))
plt.yticks(range(0, 7, 1))
plt.show()

# %%
import pandas as pd 
teploty = pd.read_csv("temperature.csv")
teploty
# Out:
#              Region  Country      City  Day  AvgTemperature
# 0            Africa  Algeria   Algiers    1            62.0
# 1            Africa  Algeria   Algiers    2            62.2
# 2            Africa  Algeria   Algiers    3            65.7
# 3            Africa  Algeria   Algiers    4            69.8
# 4            Africa  Algeria   Algiers    5            63.8
# ...             ...      ...       ...  ...             ...
# 8785  North America       US  Cheyenne   26            51.7
# 8786  North America       US  Cheyenne   27            55.5
# 8787  North America       US  Cheyenne   28            38.5
# 8788  North America       US  Cheyenne   29            36.8
# 8789  North America       US  Cheyenne   30            36.9
#
# [8790 rows x 5 columns]

# %%
teploty[teploty["City"].isin(["Helsinki","Miami Beach","Tokyo"])].head()
# Out:
#      Region Country   City  Day  AvgTemperature
# 1140   Asia   Japan  Tokyo    1            59.1
# 1141   Asia   Japan  Tokyo    2            62.3
# 1142   Asia   Japan  Tokyo    3            64.1
# 1143   Asia   Japan  Tokyo    4            59.6
# 1144   Asia   Japan  Tokyo    5            57.0

# %%
teploty.plot(kind="box", column="AvgTemperature", by="City")
plt.show()

# %%
data = teploty[teploty["City"].isin(["Helsinki", "Miami Beach", "Tokyo"])]

# %%
data_pivot = pd.pivot(data, index="Day", columns="City", values="AvgTemperature")
data_pivot
# Out:
# City  Helsinki  Miami Beach  Tokyo
# Day
# 1         29.6         74.6   59.1
# 2         29.5         76.8   62.3
# 3         35.1         77.4   64.1
# 4         44.5         77.4   59.6
# 5         45.5         77.2   57.0
# 6         43.8         78.6   60.4
# 7         36.0         78.8   64.0
# 8         38.6         79.0   62.5
# 9         42.4         80.0   59.0
# 10        43.0         80.2   62.1
# 11        40.5         79.1   59.5
# 12        35.7         80.8   55.1
# 13        34.6         79.2   56.8
# 14        33.1         79.7   56.2
# 15        34.4         75.4   56.7
# 16        36.1         75.0   53.7
# 17        40.6         73.8   53.1
# 18        39.8         75.1   53.5
# 19        37.2         75.2   48.9
# 20        33.0         74.5   46.6
# 21        32.4         74.4   48.2
# 22        32.3         77.3   48.7
# 23        33.5         77.4   53.4
# 24        41.9         75.9   50.3
# 25        36.0         72.1   50.5
# ...

# %%
data_pivot.plot(kind="box")
# Out:
# <Axes: >
