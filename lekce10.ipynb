# %%
import pandas as pd
staty = pd.read_json("staty.json")
staty.set_index("name", inplace=True)
staty[["population", "area"]]
staty["density"] = staty["population"] / staty["area"]
staty.sort_values("density", ascending=False)
staty.head(20)
# Out:
#                     alpha2Code alpha3Code           capital    region  \
# name
# Afghanistan                 AF        AFG             Kabul      Asia
# Åland Islands               AX        ALA         Mariehamn    Europe
# Albania                     AL        ALB            Tirana    Europe
# Algeria                     DZ        DZA           Algiers    Africa
# American Samoa              AS        ASM         Pago Pago   Oceania
# Andorra                     AD        AND  Andorra la Vella    Europe
# Angola                      AO        AGO            Luanda    Africa
# Anguilla                    AI        AIA        The Valley  Americas
# Antarctica                  AQ        ATA                       Polar
# Antigua and Barbuda         AG        ATG      Saint John's  Americas
# Argentina                   AR        ARG      Buenos Aires  Americas
# Armenia                     AM        ARM           Yerevan      Asia
# ...

# %%
import pandas as pd
studenti_1 = pd.read_csv("studenti1.csv")
studenti_1.head()
# Out:
#      jméno    příjmení                      obor  ročník  kruh  prospěch
# 0  Ludmila  Šindlerová  informatika a management     4.0  11.0      2.49
# 1      Jan     Pekárek    softwarové inženýrství     1.0   7.0      1.05
# 2    Milan       Weiss        počítačová grafika     5.0  11.0      2.62
# 3   Jiřina     Petrová         správa IT systémů     4.0   1.0      1.15
# 4    Josef    Navrátil        číslicová technika     5.0   7.0      2.42

# %%
import pandas as pd
studenti_2 = pd.read_csv("studenti2.csv")
studenti_2.head()
# Out:
#      jméno   příjmení                      obor  ročník  kruh  prospěch
# 0     Petr    Vanžura         správa IT systémů     3.0   3.0      2.24
# 1    Josef      Pícha        webové inženýrství     2.0   9.0      2.52
# 2   Michal    Steiner  informatika a management     2.0   2.0      2.33
# 3   Renata  Václavová  informatika a management     2.0   3.0      2.83
# 4  Jarmila    Selucká  informatika a management     NaN   6.0      2.34

# %%
studenti_1.shape
# Out:
# (205, 6)

# %%
studenti_2.shape
# Out:
# (140, 6)

# %%
studenti = pd.concat([studenti_1, studenti_2])
studenti.head
# Out:
# <bound method NDFrame.head of        jméno      příjmení                      obor  ročník  kruh  prospěch
# 0    Ludmila    Šindlerová  informatika a management     4.0  11.0      2.49
# 1        Jan       Pekárek    softwarové inženýrství     1.0   7.0      1.05
# 2      Milan         Weiss        počítačová grafika     5.0  11.0      2.62
# 3     Jiřina       Petrová         správa IT systémů     4.0   1.0      1.15
# 4      Josef      Navrátil        číslicová technika     5.0   7.0      2.42
# ..       ...           ...                       ...     ...   ...       ...
# 135   Daniel  Brandstätter  informatika a management     4.0   2.0      2.05
# 136    Lukáš          Čech  informatika a management     5.0   NaN      1.59
# 137   Dagmar      Košanová    teoretická informatika     5.0  10.0      1.34
# 138    Ivana    Macháčková        webové inženýrství     1.0   NaN      2.92
# 139  Martina       Turková    softwarové inženýrství     5.0   8.0      1.54
#
# ...

# %%
studenti.shape
# Out:
# (345, 6)

# %%
studenti[studenti["ročník"].isnull()].shape[0]
# Out:
# (33, 6)

# %%
studenti.isnull().sum()
# Out:
# jméno        0
# příjmení     0
# obor         0
# ročník      33
# kruh        27
# prospěch     0
# dtype: int64

# %%
studenti.dropna(inplace=True)

# %%
studenti.groupby("obor").count()
# Out:
#                           jméno  příjmení  ročník  kruh  prospěch
# obor
# informatika a management     49        49      49    49        49
# počítačová grafika           33        33      33    33        33
# softwarové inženýrství       41        41      41    41        41
# správa IT systémů            38        38      38    38        38
# teoretická informatika       47        47      47    47        47
# webové inženýrství           46        46      46    46        46
# číslicová technika           33        33      33    33        33
